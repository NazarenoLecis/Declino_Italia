# %% [markdown]
# # Grafici su PIL e produttivita
#
# Questa categoria genera grafici su PIL, PIL pro capite e produttivita. Per ciascun grafico sono indicate fonte primaria, fonti ufficiali alternative e trasformazione applicata.
#
# Ogni grafico riporta la fonte primaria usata nella generazione e la dicitura `elaborazione Nazareno Lecis`.

# %% [markdown]
# ## Come vengono generati
#
# Il notebook separa tre cose: la specifica del grafico, la fonte dati e la trasformazione. Ogni specifica dichiara `titolo`, `tipo_grafico`, `anno_inizio`, `ultimo_dato`, fonte primaria, fonti alternative e cosa viene mostrato. `definisci_grafico_da_indicatore_world_bank` usa direttamente un indicatore WDI; `definisci_grafico_da_rapporto_world_bank` combina due serie WDI; `registra_grafico_da_collegare_a_api` mantiene in inventario un grafico per cui la fonte pubblica esiste ma non e ancora mappata nel codice.
#
# Quando il grafico viene generato, `genera_grafici_e_inventario` scarica i dati via API, applica la trasformazione indicata, costruisce il confronto con Italia, min-max, percentili 25-75 e mediana dei paesi avanzati quando disponibile, poi mostra l'inventario e lascia il plot nel notebook.

# %%
from pathlib import Path
import sys

import pandas as pd

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "analisi").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from analisi.utils.grafici import (
    PAESI_MONDO,
    definisci_grafico_da_rapporto_world_bank,
    definisci_grafico_da_indicatore_world_bank,
    genera_grafici_e_inventario,
    registra_grafico_da_collegare_a_api,
)

from sources.api_catalog import FONTI_API

# %% [markdown]
# ## Fonti disponibili per questa categoria
#
# La tabella sotto elenca le API ufficiali considerate per la categoria. Una stessa variabile puo comparire in piu fonti: il notebook indica una fonte primaria per la generazione, ma mantiene le alternative quando esistono definizioni ufficiali equivalenti o vicine.

# %%
fonti_categoria = ('Commissione europea - AMECO API', 'IMF DataMapper API', 'OECD SDMX API', 'Eurostat API')
catalogo_fonti_api = pd.DataFrame(
    [
        {
            "fonte": fonte.nome,
            "ente": fonte.ente,
            "aree": ", ".join(fonte.aree),
            "note": fonte.note,
            "endpoint_controllo": fonte.url_controllo,
        }
        for fonte in FONTI_API
        if fonte.nome in fonti_categoria
    ]
)
catalogo_fonti_api

# %% [markdown]
# ## Specifiche dei grafici
#
# Le righe sotto sono volutamente esplicite: per ogni grafico si legge il titolo dell'analisi, il tipo di grafico, la fonte primaria, le fonti ufficiali alternative, l'anno di partenza, l'ultimo dato richiesto e la trasformazione applicata.

# %%
SPECIFICHE_GRAFICI = [
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale aggregato - crescita media',
        nome_output='pil_reale_aggregato_crescita_media',
        indicatore='NY.GDP.MKTP.KD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale aggregato - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale aggregato - crescita cumulata',
        nome_output='pil_reale_aggregato_crescita_cumulata',
        indicatore='NY.GDP.MKTP.KD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale aggregato - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale pro capite - crescita media',
        nome_output='pil_reale_pro_capite_crescita_media',
        indicatore='NY.GDP.PCAP.KD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale pro capite - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale pro capite - crescita cumulata',
        nome_output='pil_reale_pro_capite_crescita_cumulata',
        indicatore='NY.GDP.PCAP.KD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale pro capite - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL nominale aggregato - crescita media',
        nome_output='pil_nominale_aggregato_crescita_media',
        indicatore='NY.GDP.MKTP.CD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL nominale aggregato - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL nominale aggregato - crescita cumulata',
        nome_output='pil_nominale_aggregato_crescita_cumulata',
        indicatore='NY.GDP.MKTP.CD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL nominale aggregato - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL nominale pro capite - crescita media',
        nome_output='pil_nominale_pro_capite_crescita_media',
        indicatore='NY.GDP.PCAP.CD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL nominale pro capite - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL nominale pro capite - crescita cumulata',
        nome_output='pil_nominale_pro_capite_crescita_cumulata',
        indicatore='NY.GDP.PCAP.CD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL nominale pro capite - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale aggregato in US$ - crescita media',
        nome_output='pil_reale_usd_crescita_media',
        indicatore='NY.GDP.MKTP.KD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale aggregato in US$ - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale aggregato in US$ - crescita cumulata',
        nome_output='pil_reale_usd_crescita_cumulata',
        indicatore='NY.GDP.MKTP.KD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale aggregato in US$ - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale pro capite in US$ - livello',
        nome_output='pil_reale_pro_capite_usd_livello',
        indicatore='NY.GDP.PCAP.KD',
        trasformazione='level',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale pro capite in US$ - livello: livello della serie, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale pro capite in US$ - crescita media',
        nome_output='pil_reale_pro_capite_usd_crescita_media',
        indicatore='NY.GDP.PCAP.KD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale pro capite in US$ - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale pro capite in US$ - crescita cumulata',
        nome_output='pil_reale_pro_capite_usd_crescita_cumulata',
        indicatore='NY.GDP.PCAP.KD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale pro capite in US$ - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL nominale in US$ - crescita media',
        nome_output='pil_nominale_usd_crescita_media',
        indicatore='NY.GDP.MKTP.CD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL nominale in US$ - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL nominale in US$ - crescita cumulata',
        nome_output='pil_nominale_usd_crescita_cumulata',
        indicatore='NY.GDP.MKTP.CD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL nominale in US$ - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL nominale pro capite in US$ - crescita media',
        nome_output='pil_nominale_pro_capite_usd_crescita_media',
        indicatore='NY.GDP.PCAP.CD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL nominale pro capite in US$ - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL nominale pro capite in US$ - crescita cumulata',
        nome_output='pil_nominale_pro_capite_usd_crescita_cumulata',
        indicatore='NY.GDP.PCAP.CD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL nominale pro capite in US$ - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale pro capite in PPP - livello',
        nome_output='pil_reale_pro_capite_ppp_livello',
        indicatore='NY.GDP.PCAP.PP.KD',
        trasformazione='level',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale pro capite in PPP - livello: livello della serie, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale pro capite in PPP - crescita media',
        nome_output='pil_reale_pro_capite_ppp_crescita_media',
        indicatore='NY.GDP.PCAP.PP.KD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale pro capite in PPP - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='PIL reale pro capite in PPP - crescita cumulata',
        nome_output='pil_reale_pro_capite_ppp_crescita_cumulata',
        indicatore='NY.GDP.PCAP.PP.KD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale pro capite in PPP - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_rapporto_world_bank(
        titolo='PIL reale per persona in eta lavorativa - crescita media',
        nome_output='pil_per_persona_eta_lavorativa_crescita_media',
        numeratore='NY.GDP.MKTP.KD',
        denominatore='SP.POP.1564.TO',
        scala=1.0,
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale per persona in eta lavorativa - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_rapporto_world_bank(
        titolo='PIL reale per persona in eta lavorativa - crescita cumulata',
        nome_output='pil_per_persona_eta_lavorativa_crescita_cumulata',
        numeratore='NY.GDP.MKTP.KD',
        denominatore='SP.POP.1564.TO',
        scala=1.0,
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='PIL reale per persona in eta lavorativa - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='Quota italiana del PIL reale mondiale',
        nome_output='quota_pil_reale_mondiale',
        indicatore='NY.GDP.MKTP.PP.KD',
        trasformazione='share_world',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra="Quota italiana del PIL reale mondiale: quota dell'Italia sul totale mondiale, senza distribuzione dei paesi avanzati.",
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
        confronto=False,
        paesi=tuple(PAESI_MONDO),
    ),
    registra_grafico_da_collegare_a_api(
        titolo='PIL potenziale',
        nome_output='pil_potenziale',
        fonte_primaria='Commissione europea - AMECO API',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        cosa_mostra='PIL potenziale: Richiede mapping AMECO per output gap/potential GDP.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API'),
        note='Richiede mapping AMECO per output gap/potential GDP.',
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='Produttivita per ora lavorata',
        nome_output='produttivita_per_ora_lavorata_proxy',
        indicatore='SL.GDP.PCAP.EM.KD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='Produttivita per ora lavorata: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='Produttivita per addetto',
        nome_output='produttivita_per_addetto',
        indicatore='SL.GDP.PCAP.EM.KD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='Produttivita per addetto: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
    ),
    registra_grafico_da_collegare_a_api(
        titolo='Produttivita strutturale, TFP, labour share e grafici Euro',
        nome_output='produttivita_tfp_euro',
        fonte_primaria='DG ECFIN/OECD SDMX API',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        cosa_mostra='Produttivita strutturale, TFP, labour share e grafici Euro: Richiede mapping API per TFP, labour share e indici OECD.',
        fonti_alternative=('IMF DataMapper API', 'OECD SDMX API', 'Eurostat API', 'Commissione europea - AMECO API'),
        note='Richiede mapping API per TFP, labour share e indici OECD.',
    ),
]

print(f"Specifiche nella categoria: {len(SPECIFICHE_GRAFICI)}")

# %% [markdown]
# ## Inventario e generazione
#
# La tabella risultante mostra cosa viene prodotto, quale fonte e stata usata, quali alternative sono possibili, da quale anno parte la serie, fino a quale ultimo dato viene richiesto e quali grafici restano da collegare.

# %%
cartella_output = ROOT / "analisi" / "pil"
percorsi, inventario = genera_grafici_e_inventario(SPECIFICHE_GRAFICI, cartella_output)

colonne = [
    "titolo",
    "tipo_grafico",
    "cosa_mostra",
    "fonte_primaria",
    "fonti_alternative",
    "anno_inizio",
    "ultimo_dato",
    "trasformazione",
    "confronto",
    "stato",
    "nome_output",
    "note",
    "errore",
]
print(f"PNG generati: {len(percorsi)}")
for percorso in percorsi:
    print(percorso)
inventario[colonne]

# %% [markdown]
# ## Plot dei grafici generati
#
# I plot visualizzati qui sono quelli creati dalla cella precedente. I PNG locali restano fuori da Git.

# %%
from IPython.display import Image, display

if not percorsi:
    print("Nessun PNG generato: tutti i grafici della categoria sono ancora da collegare o la fonte non ha restituito dati.")
for percorso in percorsi:
    display(Image(filename=str(percorso)))
