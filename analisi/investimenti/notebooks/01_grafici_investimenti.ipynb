# %% [markdown]
# # Grafici su investimenti
#
# Questa categoria genera o registra grafici su formazione di capitale, investimenti fissi, componenti e stock di capitale. World Bank copre gli aggregati, AMECO/OECD/Eurostat servono per le scomposizioni.
#
# Ogni grafico riporta la fonte primaria usata nella generazione e la dicitura `elaborazione Nazareno Lecis`.

# %% [markdown]
# ## Come vengono generati
#
# Il notebook separa tre cose: la specifica del grafico, la fonte dati e la trasformazione. Ogni specifica dichiara `titolo`, `tipo_grafico`, `anno_inizio`, `ultimo_dato`, fonte primaria, fonti alternative e cosa viene mostrato. `definisci_grafico_da_indicatore_world_bank` usa direttamente un indicatore WDI; `definisci_grafico_da_rapporto_world_bank` combina due serie WDI; `registra_grafico_da_collegare_a_api` mantiene in inventario un grafico per cui la fonte pubblica esiste ma non e ancora mappata nel codice.
#
# Quando il grafico viene generato, `genera_grafici_e_inventario` scarica i dati via API, applica la trasformazione indicata, costruisce il confronto con Italia, min-max, percentili 25-75 e mediana dei paesi avanzati quando disponibile, poi mostra l'inventario e lascia il plot nel notebook.

# %%
from pathlib import Path
import sys

import pandas as pd

ROOT = Path.cwd().resolve()
while ROOT != ROOT.parent and not (ROOT / "analisi").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from analisi.utils.grafici import (
    PAESI_MONDO,
    definisci_grafico_da_rapporto_world_bank,
    definisci_grafico_da_indicatore_world_bank,
    genera_grafici_e_inventario,
    registra_grafico_da_collegare_a_api,
)

from sources.api_catalog import FONTI_API

# %% [markdown]
# ## Fonti disponibili per questa categoria
#
# La tabella sotto elenca le API ufficiali considerate per la categoria. Una stessa variabile puo comparire in piu fonti: il notebook indica una fonte primaria per la generazione, ma mantiene le alternative quando esistono definizioni ufficiali equivalenti o vicine.

# %%
fonti_categoria = ('Commissione europea - AMECO API', 'World Bank API', 'OECD SDMX API', 'Eurostat API', 'IMF DataMapper API')
catalogo_fonti_api = pd.DataFrame(
    [
        {
            "fonte": fonte.nome,
            "ente": fonte.ente,
            "aree": ", ".join(fonte.aree),
            "note": fonte.note,
            "endpoint_controllo": fonte.url_controllo,
        }
        for fonte in FONTI_API
        if fonte.nome in fonti_categoria
    ]
)
catalogo_fonti_api

# %% [markdown]
# ## Specifiche dei grafici
#
# Le righe sotto sono volutamente esplicite: per ogni grafico si legge il titolo dell'analisi, il tipo di grafico, la fonte primaria, le fonti ufficiali alternative, l'anno di partenza, l'ultimo dato richiesto e la trasformazione applicata.

# %%
SPECIFICHE_GRAFICI = [
    definisci_grafico_da_indicatore_world_bank(
        titolo='Formazione di capitale - crescita media',
        nome_output='formazione_capitale_crescita_media',
        indicatore='NE.GDI.TOTL.KD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='Formazione di capitale - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('Commissione europea - AMECO API', 'OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='Formazione di capitale - crescita cumulata',
        nome_output='formazione_capitale_crescita_cumulata',
        indicatore='NE.GDI.TOTL.KD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='Formazione di capitale - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('Commissione europea - AMECO API', 'OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
    ),
    definisci_grafico_da_rapporto_world_bank(
        titolo='Formazione di capitale pro capite - crescita media',
        nome_output='formazione_capitale_pro_capite_crescita_media',
        numeratore='NE.GDI.TOTL.KD',
        denominatore='SP.POP.TOTL',
        scala=1.0,
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='Formazione di capitale pro capite - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('Commissione europea - AMECO API', 'OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
    ),
    definisci_grafico_da_rapporto_world_bank(
        titolo='Formazione di capitale pro capite - crescita cumulata',
        nome_output='formazione_capitale_pro_capite_crescita_cumulata',
        numeratore='NE.GDI.TOTL.KD',
        denominatore='SP.POP.TOTL',
        scala=1.0,
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='Formazione di capitale pro capite - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('Commissione europea - AMECO API', 'OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='Formazione di capitale fisso - crescita media',
        nome_output='formazione_capitale_fisso_crescita_media',
        indicatore='NE.GDI.FTOT.KD',
        trasformazione='growth_10y',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='Formazione di capitale fisso - crescita media: tasso di crescita annualizzato su 10 anni, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('Commissione europea - AMECO API', 'OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='Formazione di capitale fisso - crescita cumulata',
        nome_output='formazione_capitale_fisso_crescita_cumulata',
        indicatore='NE.GDI.FTOT.KD',
        trasformazione='index',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='Formazione di capitale fisso - crescita cumulata: indice con base 1970=100, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('Commissione europea - AMECO API', 'OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
    ),
    registra_grafico_da_collegare_a_api(
        titolo='Investimenti in costruzioni',
        nome_output='investimenti_costruzioni',
        fonte_primaria='Commissione europea - AMECO API',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        cosa_mostra='Investimenti in costruzioni: Crescita media e cumulata della componente costruzioni.',
        fonti_alternative=('OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
        note='Crescita media e cumulata della componente costruzioni.',
    ),
    registra_grafico_da_collegare_a_api(
        titolo='Investimenti in alloggi',
        nome_output='investimenti_alloggi',
        fonte_primaria='Commissione europea - AMECO API',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        cosa_mostra='Investimenti in alloggi: Crescita media e cumulata della componente abitazioni.',
        fonti_alternative=('OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
        note='Crescita media e cumulata della componente abitazioni.',
    ),
    registra_grafico_da_collegare_a_api(
        titolo='Costruzioni non residenziali',
        nome_output='costruzioni_non_residenziali',
        fonte_primaria='Commissione europea - AMECO API',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        cosa_mostra='Costruzioni non residenziali: Crescita media e cumulata.',
        fonti_alternative=('OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
        note='Crescita media e cumulata.',
    ),
    registra_grafico_da_collegare_a_api(
        titolo='Investimenti in capitale fisico',
        nome_output='investimenti_capitale_fisico',
        fonte_primaria='Commissione europea - AMECO API',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        cosa_mostra='Investimenti in capitale fisico: Crescita media e cumulata.',
        fonti_alternative=('OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
        note='Crescita media e cumulata.',
    ),
    registra_grafico_da_collegare_a_api(
        titolo='Investimenti in mezzi di trasporto',
        nome_output='investimenti_mezzi_trasporto',
        fonte_primaria='Commissione europea - AMECO API',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        cosa_mostra='Investimenti in mezzi di trasporto: Crescita media e cumulata.',
        fonti_alternative=('OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
        note='Crescita media e cumulata.',
    ),
    registra_grafico_da_collegare_a_api(
        titolo='Formazione netta di capitale e stock netto',
        nome_output='formazione_netta_capitale',
        fonte_primaria='Commissione europea - AMECO API',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        cosa_mostra='Formazione netta di capitale e stock netto: Settore pubblico, privato, totale, stock e quota dello stock.',
        fonti_alternative=('OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
        note='Settore pubblico, privato, totale, stock e quota dello stock.',
    ),
    definisci_grafico_da_indicatore_world_bank(
        titolo='Investimenti totali - % del PIL',
        nome_output='investimenti_totali_pil',
        indicatore='NE.GDI.TOTL.ZS',
        trasformazione='level',
        tipo_grafico='serie_storica',
        anno_inizio=1960,
        ultimo_dato='latest',
        fonte_primaria='World Bank API',
        cosa_mostra='Investimenti totali - % del PIL: livello della serie, con confronto Italia-distribuzione paesi avanzati.',
        fonti_alternative=('Commissione europea - AMECO API', 'OECD SDMX API', 'Eurostat API', 'IMF DataMapper API'),
    ),
]

print(f"Specifiche nella categoria: {len(SPECIFICHE_GRAFICI)}")

# %% [markdown]
# ## Inventario e generazione
#
# La tabella risultante mostra cosa viene prodotto, quale fonte e stata usata, quali alternative sono possibili, da quale anno parte la serie, fino a quale ultimo dato viene richiesto e quali grafici restano da collegare.

# %%
cartella_output = ROOT / "analisi" / "investimenti"
percorsi, inventario = genera_grafici_e_inventario(SPECIFICHE_GRAFICI, cartella_output)

colonne = [
    "titolo",
    "tipo_grafico",
    "cosa_mostra",
    "fonte_primaria",
    "fonti_alternative",
    "anno_inizio",
    "ultimo_dato",
    "trasformazione",
    "confronto",
    "stato",
    "nome_output",
    "note",
    "errore",
]
print(f"PNG generati: {len(percorsi)}")
for percorso in percorsi:
    print(percorso)
inventario[colonne]

# %% [markdown]
# ## Plot dei grafici generati
#
# I plot visualizzati qui sono quelli creati dalla cella precedente. I PNG locali restano fuori da Git.

# %%
from IPython.display import Image, display

if not percorsi:
    print("Nessun PNG generato: tutti i grafici della categoria sono ancora da collegare o la fonte non ha restituito dati.")
for percorso in percorsi:
    display(Image(filename=str(percorso)))
